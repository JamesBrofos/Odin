# %%
import fund
import settings
import handlers

# %%
from odin.metrics import Visualizer

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
fund.fund.trade()
# Out:
# FILL	2012-01-03 00:00:00	SPY	LONG	BUY	867	100095.34

# %%
fund.fund.performance_summary()
# Out:
#                     total equity     max equity  max drawdown  max duration  \
# long_buy_and_hold  196059.070041  196059.070041      0.133429         188.0
# fund               196059.070041  196059.070041      0.133429         188.0
#
#                    sharpe ratio  avg positions  annualized returns
# long_buy_and_hold      1.112982            1.0             1.14513
# fund                   1.112982            1.0             1.14513

# %%
v = Visualizer()

# %%
plt.figure(figsize=(17, 8))
ax1 = plt.subplot(211)
ax1 = v.equity(fund.fund, ax=ax1)
ax2 = plt.subplot(212, sharex=ax1)
ax2 = v.positions(fund.fund, ax=ax2)
plt.show()
