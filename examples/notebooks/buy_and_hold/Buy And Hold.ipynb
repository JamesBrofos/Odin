# %%
import fund
import settings
import handlers

# %%
from odin.metrics import Visualizer

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
fund.fund.trade()
# Out:
# FILL	2006-01-03 00:00:00	SPY	LONG	BUY	1016	100448.58

# %%
fund.fund.performance_summary()
# Out:
#                total equity     max equity  max drawdown  max duration  \
# buy_and_hold  264031.468284  264031.468284       0.55618        1222.0
# fund          264031.468284  264031.468284       0.55618        1222.0
#
#               sharpe ratio  avg positions  annualized returns  \
# buy_and_hold      0.526663            1.0            1.085096
# fund              0.526663            1.0            1.085096
#
#               prop positive days
# buy_and_hold            0.545728
# fund                    0.545728

# %%
v = Visualizer()

# %%
plt.figure(figsize=(17, 4))
ax1 = plt.subplot(111)
ax1 = v.equity(fund.fund, ax=ax1)
plt.show()

# %%
plt.figure(figsize=(17, 8))
ax1 = plt.subplot(211)
ax1 = v.drawdown_percentage(fund.fund, ax=ax1)
ax2 = plt.subplot(212, sharex=ax1)
ax2 = v.drawdown_duration(fund.fund, ax=ax2)
plt.show()

# %%
plt.figure(figsize=(17, 4))
ax1 = plt.subplot(111)
ax1 = v.rolling_sharpe(252, fund.fund, ax=ax1)
plt.show()
