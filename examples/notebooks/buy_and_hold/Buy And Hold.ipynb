# %%
import fund
import settings
import handlers

# %%
from odin.metrics import Visualizer

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
fund.fund.trade()
# Out:
# FILL	2012-01-03 00:00:00	SPY	LONG	BUY	867	100095.34

# %%
fund.fund.performance_summary()
# Out:
#        total equity     max equity  max drawdown  max duration  sharpe ratio  \
# long  113569.374355  116531.948885      0.098084          96.0      1.074434
# fund  113569.374355  116531.948885      0.098084          96.0      1.074434
#
#       avg positions  annualized returns
# long            1.0            1.139881
# fund            1.0            1.139881

# %%
v = Visualizer()

# %%
plt.figure(figsize=(17, 8))
ax1 = plt.subplot(211)
ax1 = v.equity(fund.fund, ax=ax1)
ax2 = plt.subplot(212, sharex=ax1)
ax2 = v.positions(fund.fund, ax=ax2)
plt.show()
