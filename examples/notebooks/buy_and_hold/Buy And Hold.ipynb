# %%
import fund
import settings
import handlers

# %%
from odin.metrics import Visualizer

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
fund.fund.trade()
# Out:
# FILL	2006-01-03 00:00:00	SPY	LONG	BUY	1001	100376.38

# %%
fund.fund.performance_summary()
# Out:
#                     total equity     max equity  max drawdown  max duration  \
# long_buy_and_hold  224573.338321  226415.189332      0.555869        1222.0
# fund               224573.338321  226415.189332      0.555869        1222.0
#
#                    sharpe ratio  avg positions  annualized returns
# long_buy_and_hold      0.472311            1.0            1.076411
# fund                   0.472311            1.0            1.076411

# %%
v = Visualizer()

# %%
plt.figure(figsize=(17, 4))
ax1 = plt.subplot(111)
ax1 = v.equity(fund.fund, ax=ax1)
plt.show()

# %%
plt.figure(figsize=(17, 8))
ax1 = plt.subplot(211)
ax1 = v.drawdown_percentage(fund.fund, ax=ax1)
ax2 = plt.subplot(212, sharex=ax1)
ax2 = v.drawdown_duration(fund.fund, ax=ax2)
plt.show()
