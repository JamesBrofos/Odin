# %%
import fund
import settings
import handlers

# %%
from odin.metrics import Visualizer

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
fund.fund.trade()
# Out:
# FILL	2012-01-03 00:00:00	GOOG	LONG	BUY	306	100969.50
# FILL	2012-03-29 00:00:00	GOOG	LONG	EXIT	306	99369.13
# REBALANCE	2012-03-29 00:00:00
# FILL	2012-03-30 00:00:00	AMZN	LONG	BUY	58	11858.81
# FILL	2012-03-30 00:00:00	GOOG	LONG	BUY	265	85717.27
# FILL	2012-06-26 00:00:00	GOOG	LONG	EXIT	265	74491.14
# FILL	2012-06-26 00:00:00	AMZN	LONG	EXIT	58	12980.87
# REBALANCE	2012-06-26 00:00:00
# FILL	2012-06-27 00:00:00	AMZN	LONG	BUY	94	21198.19
# FILL	2012-06-27 00:00:00	GOOG	LONG	BUY	236	67227.11
# FILL	2012-09-21 00:00:00	GOOG	LONG	EXIT	236	86307.98
# FILL	2012-09-21 00:00:00	AMZN	LONG	EXIT	94	24368.59
# REBALANCE	2012-09-21 00:00:00
# FILL	2012-09-24 00:00:00	AMZN	LONG	BUY	173	44015.90
# FILL	2012-09-24 00:00:00	FB	LONG	BUY	1015	21498.29
# FILL	2012-09-24 00:00:00	GOOG	LONG	BUY	121	44756.48
# FILL	2012-12-19 00:00:00	GOOG	LONG	EXIT	121	43485.13
# FILL	2012-12-19 00:00:00	FB	LONG	EXIT	1015	27984.78
# FILL	2012-12-19 00:00:00	AMZN	LONG	EXIT	173	44901.31
# REBALANCE	2012-12-19 00:00:00
# FILL	2012-12-20 00:00:00	AMZN	LONG	BUY	180	46728.85
# FILL	2012-12-20 00:00:00	FB	LONG	BUY	848	23217.12
# FILL	2012-12-20 00:00:00	GOOG	LONG	BUY	129	46469.10
# FILL	2013-03-18 00:00:00	GOOG	LONG	EXIT	129	51981.00
# FILL	2013-03-18 00:00:00	FB	LONG	EXIT	848	22278.54
# FILL	2013-03-18 00:00:00	AMZN	LONG	EXIT	180	46651.56
# REBALANCE	2013-03-18 00:00:00
# FILL	2013-03-19 00:00:00	AMZN	LONG	BUY	152	38940.58
# FILL	2013-03-19 00:00:00	FB	LONG	BUY	1253	33290.05
# FILL	2013-03-19 00:00:00	GOOG	LONG	BUY	119	48340.50
# FILL	2013-06-13 00:00:00	GOOG	LONG	EXIT	119	51840.80
# FILL	2013-06-13 00:00:00	FB	LONG	EXIT	1253	29493.40
# FILL	2013-06-13 00:00:00	AMZN	LONG	EXIT	152	41558.05
# REBALANCE	2013-06-13 00:00:00
# FILL	2013-06-14 00:00:00	AMZN	LONG	BUY	155	42685.86
# FILL	2013-06-14 00:00:00	FB	LONG	BUY	1327	31299.67
# FILL	2013-06-14 00:00:00	GOOG	LONG	BUY	112	49222.73
# FILL	2013-09-10 00:00:00	GOOG	LONG	EXIT	112	49653.57
# FILL	2013-09-10 00:00:00	FB	LONG	EXIT	1327	58020.59
# FILL	2013-09-10 00:00:00	AMZN	LONG	EXIT	155	46338.87
# REBALANCE	2013-09-10 00:00:00
# FILL	2013-09-11 00:00:00	AMZN	LONG	BUY	206	61799.98
# FILL	2013-09-11 00:00:00	FB	LONG	BUY	710	31326.66
# FILL	2013-09-11 00:00:00	GOOG	LONG	BUY	137	61039.06
# FILL	2013-12-06 00:00:00	GOOG	LONG	EXIT	137	72846.04
# FILL	2013-12-06 00:00:00	FB	LONG	EXIT	710	34453.26
# FILL	2013-12-06 00:00:00	AMZN	LONG	EXIT	206	79494.77
# REBALANCE	2013-12-06 00:00:00
# FILL	2013-12-09 00:00:00	AMZN	LONG	BUY	186	71718.38
# FILL	2013-12-09 00:00:00	FB	LONG	BUY	964	46637.53
# FILL	2013-12-09 00:00:00	GOOG	LONG	BUY	127	68238.99
# FILL	2014-03-05 00:00:00	GOOG	LONG	EXIT	127	77179.36
# FILL	2014-03-05 00:00:00	FB	LONG	EXIT	964	68212.26
# FILL	2014-03-05 00:00:00	AMZN	LONG	EXIT	186	68472.34
# REBALANCE	2014-03-05 00:00:00
# FILL	2014-03-06 00:00:00	AMZN	LONG	BUY	228	84884.64
# FILL	2014-03-06 00:00:00	FB	LONG	BUY	595	42307.79
# FILL	2014-03-06 00:00:00	GOOG	LONG	BUY	140	85523.66
# FILL	2014-06-02 00:00:00	GOOG	LONG	EXIT	140	77425.72
# FILL	2014-06-02 00:00:00	FB	LONG	EXIT	595	37359.21
# FILL	2014-06-02 00:00:00	AMZN	LONG	EXIT	228	70599.08
# REBALANCE	2014-06-02 00:00:00
# FILL	2014-06-03 00:00:00	AMZN	LONG	BUY	162	49677.02
# FILL	2014-06-03 00:00:00	FB	LONG	BUY	994	62524.03
# FILL	2014-06-03 00:00:00	GOOG	LONG	BUY	135	73942.36
# FILL	2014-08-28 00:00:00	GOOG	LONG	EXIT	135	76935.49
# FILL	2014-08-28 00:00:00	FB	LONG	EXIT	994	73598.70
# FILL	2014-08-28 00:00:00	AMZN	LONG	EXIT	162	55100.23
# REBALANCE	2014-08-28 00:00:00
# FILL	2014-08-29 00:00:00	AMZN	LONG	BUY	120	40790.38
# FILL	2014-08-29 00:00:00	FB	LONG	BUY	1110	82641.95
# FILL	2014-08-29 00:00:00	GOOG	LONG	BUY	144	82057.23
# FILL	2014-11-25 00:00:00	GOOG	LONG	EXIT	144	77907.28
# FILL	2014-11-25 00:00:00	FB	LONG	EXIT	1110	83136.26
# FILL	2014-11-25 00:00:00	AMZN	LONG	EXIT	120	40036.57
# REBALANCE	2014-11-25 00:00:00
# FILL	2014-11-26 00:00:00	AMZN	LONG	BUY	150	50004.99
# FILL	2014-11-26 00:00:00	FB	LONG	BUY	939	72005.64
# FILL	2014-11-26 00:00:00	GOOG	LONG	BUY	147	79316.51
# FILL	2015-02-20 00:00:00	GOOG	LONG	EXIT	147	79307.61
# FILL	2015-02-20 00:00:00	FB	LONG	EXIT	939	74866.57
# FILL	2015-02-20 00:00:00	AMZN	LONG	EXIT	150	56937.02
# REBALANCE	2015-02-20 00:00:00
# FILL	2015-02-23 00:00:00	AMZN	LONG	BUY	110	41960.67
# FILL	2015-02-23 00:00:00	FB	LONG	BUY	1058	83925.47
# FILL	2015-02-23 00:00:00	GOOG	LONG	BUY	157	83711.36
# FILL	2015-05-20 00:00:00	GOOG	LONG	EXIT	157	84415.29
# FILL	2015-05-20 00:00:00	FB	LONG	EXIT	1058	84893.77
# FILL	2015-05-20 00:00:00	AMZN	LONG	EXIT	110	46477.05
# REBALANCE	2015-05-20 00:00:00
# FILL	2015-05-21 00:00:00	AMZN	LONG	BUY	101	43699.29
# FILL	2015-05-21 00:00:00	FB	LONG	BUY	1086	87466.71
# FILL	2015-05-21 00:00:00	GOOG	LONG	BUY	160	86428.79
# FILL	2015-08-17 00:00:00	GOOG	LONG	EXIT	160	104957.09
# FILL	2015-08-17 00:00:00	FB	LONG	EXIT	1086	101951.55
# FILL	2015-08-17 00:00:00	AMZN	LONG	EXIT	101	53799.02
# REBALANCE	2015-08-17 00:00:00
# FILL	2015-08-18 00:00:00	AMZN	LONG	BUY	194	104083.54
# FILL	2015-08-18 00:00:00	FB	LONG	BUY	554	52625.83
# FILL	2015-08-18 00:00:00	GOOG	LONG	BUY	157	103472.32
# FILL	2015-11-12 00:00:00	GOOG	LONG	EXIT	157	115058.38
# FILL	2015-11-12 00:00:00	FB	LONG	EXIT	554	60186.92
# FILL	2015-11-12 00:00:00	AMZN	LONG	EXIT	194	129901.44
# REBALANCE	2015-11-12 00:00:00
# FILL	2015-11-13 00:00:00	AMZN	LONG	BUY	92	60172.77
# FILL	2015-11-13 00:00:00	FB	LONG	BUY	1135	120415.58
# FILL	2015-11-13 00:00:00	GOOG	LONG	BUY	167	120958.43
# FILL	2016-02-09 00:00:00	GOOG	LONG	EXIT	167	114226.81
# FILL	2016-02-09 00:00:00	FB	LONG	EXIT	1135	113000.82
# FILL	2016-02-09 00:00:00	AMZN	LONG	EXIT	92	44707.12
# REBALANCE	2016-02-09 00:00:00
# FILL	2016-02-10 00:00:00	AMZN	LONG	BUY	224	111009.40
# FILL	2016-02-10 00:00:00	FB	LONG	BUY	543	55275.16
# FILL	2016-02-10 00:00:00	GOOG	LONG	BUY	159	110038.47
# FILL	2016-05-06 00:00:00	GOOG	LONG	EXIT	159	112036.33
# FILL	2016-05-06 00:00:00	FB	LONG	EXIT	543	64245.49
# FILL	2016-05-06 00:00:00	AMZN	LONG	EXIT	224	149216.88
# REBALANCE	2016-05-06 00:00:00
# FILL	2016-05-09 00:00:00	AMZN	LONG	BUY	96	65235.32
# FILL	2016-05-09 00:00:00	FB	LONG	BUY	1088	130178.98
# FILL	2016-05-09 00:00:00	GOOG	LONG	BUY	182	130077.62
# FILL	2016-08-03 00:00:00	GOOG	LONG	EXIT	182	140072.66
# FILL	2016-08-03 00:00:00	FB	LONG	EXIT	1088	133882.14
# FILL	2016-08-03 00:00:00	AMZN	LONG	EXIT	96	72498.45
# REBALANCE	2016-08-03 00:00:00
# FILL	2016-08-04 00:00:00	AMZN	LONG	BUY	183	138723.85
# FILL	2016-08-04 00:00:00	FB	LONG	BUY	570	70515.74
# FILL	2016-08-04 00:00:00	GOOG	LONG	BUY	177	136611.82
# FILL	2016-10-31 00:00:00	GOOG	LONG	EXIT	177	139836.16
# FILL	2016-10-31 00:00:00	FB	LONG	EXIT	570	74917.52
# FILL	2016-10-31 00:00:00	AMZN	LONG	EXIT	183	143931.61
# REBALANCE	2016-10-31 00:00:00
# FILL	2016-11-01 00:00:00	AMZN	LONG	BUY	179	141261.32
# FILL	2016-11-01 00:00:00	FB	LONG	BUY	1093	142483.64
# FILL	2016-11-01 00:00:00	GOOG	LONG	BUY	91	71244.47

# %%
fund.fund.performance_summary()
# Out:
#                    total equity     max equity  max drawdown  max duration  \
# modern_portfolio  344321.186782  374645.898796      0.195236         154.0
# fund              344321.186782  374645.898796      0.195236         154.0
#
#                   sharpe ratio  avg positions  annualized returns
# modern_portfolio      1.197156       2.760383            1.282568
# fund                  1.197156       2.760383            1.282568

# %%
v = Visualizer()

# %%
plt.figure(figsize=(17, 8))
ax1 = plt.subplot(211)
ax1 = v.equity(fund.fund, ax=ax1)
ax2 = plt.subplot(212, sharex=ax1)
ax2 = v.positions(fund.fund, ax=ax2)
plt.show()

# %%
plt.figure(figsize=(17, 8))
ax1 = plt.subplot(211)
ax1 = v.drawdown_percentage(fund.fund, ax=ax1)
ax2 = plt.subplot(212, sharex=ax1)
ax2 = v.drawdown_duration(fund.fund, ax=ax2)
plt.show()

# %%
plt.figure(figsize=(17, 4))
ax1 = plt.subplot(121)
ax1 = v.monthly_returns(fund.fund, ax=ax1)
ax2 = plt.subplot(122)
ax2 = v.yearly_returns(fund.fund, ax=ax2)
plt.show()
