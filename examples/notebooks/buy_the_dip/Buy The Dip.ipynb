# %%
import fund
import settings
import handlers

# %%
from odin.metrics import Visualizer

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
fund.fund.trade()
# Out:
# FILL	2011-01-03 00:00:00	SPY	LONG	BUY	893	99987.75
# FILL	2011-01-20 00:00:00	AMZN	LONG	BUY	269	49500.56
# FILL	2011-01-24 00:00:00	GOOG	LONG	BUY	162	49131.19
# FILL	2011-04-28 00:00:00	AMZN	LONG	EXIT	269	52302.41
# FILL	2011-05-17 00:00:00	AMZN	LONG	BUY	248	48103.80
# FILL	2011-07-01 00:00:00	AMZN	LONG	EXIT	248	51295.46
# FILL	2011-07-12 00:00:00	AMZN	LONG	BUY	232	49530.07
# FILL	2011-07-27 00:00:00	AMZN	LONG	EXIT	232	51805.20
# FILL	2011-07-28 00:00:00	SPY	LONG	BUY	464	54193.22
# FILL	2011-12-28 00:00:00	GOOG	LONG	EXIT	162	51887.77
# FILL	2012-01-10 00:00:00	AMZN	LONG	BUY	306	55031.00
# FILL	2012-01-19 00:00:00	AMZN	LONG	EXIT	306	59074.35
# FILL	2012-01-23 00:00:00	GOOG	LONG	BUY	197	57683.41
# FILL	2012-02-17 00:00:00	SPY	LONG	EXIT	464	57025.73
# FILL	2012-02-17 00:00:00	AMZN	LONG	BUY	332	60249.93
# FILL	2012-02-29 00:00:00	GOOG	LONG	EXIT	197	61032.69
# FILL	2012-03-21 00:00:00	AMZN	LONG	EXIT	332	63967.64
# FILL	2012-03-29 00:00:00	AMZN	LONG	BUY	310	62952.16
# FILL	2012-04-16 00:00:00	GOOG	LONG	BUY	193	59099.49
# FILL	2012-04-27 00:00:00	AMZN	LONG	EXIT	310	69546.26
# FILL	2012-05-07 00:00:00	AMZN	LONG	BUY	291	65385.45
# FILL	2012-07-30 00:00:00	AMZN	LONG	EXIT	291	69050.31
# FILL	2012-07-30 00:00:00	FB	LONG	BUY	2862	67390.85
# FILL	2012-08-09 00:00:00	GOOG	LONG	EXIT	193	62047.68
# FILL	2012-10-10 00:00:00	AMZN	LONG	BUY	253	62834.86
# FILL	2012-11-26 00:00:00	FB	LONG	EXIT	2862	72801.48
# FILL	2012-12-04 00:00:00	FB	LONG	BUY	2659	72414.17
# FILL	2012-12-19 00:00:00	AMZN	LONG	EXIT	253	65664.93
# FILL	2012-12-27 00:00:00	AMZN	LONG	BUY	291	71652.36
# FILL	2013-01-07 00:00:00	AMZN	LONG	EXIT	291	77425.47
# FILL	2013-01-07 00:00:00	FB	LONG	EXIT	2659	77657.13
# FILL	2013-01-15 00:00:00	FB	LONG	BUY	2567	79090.29
# FILL	2013-01-15 00:00:00	GOOG	LONG	BUY	217	78466.10
# FILL	2013-02-04 00:00:00	GOOG	LONG	EXIT	217	82810.01
# FILL	2013-02-05 00:00:00	GOOG	LONG	BUY	204	78020.72
# FILL	2013-02-20 00:00:00	GOOG	LONG	EXIT	204	81516.56
# FILL	2013-02-26 00:00:00	AMZN	LONG	BUY	299	77445.32
# FILL	2013-03-05 00:00:00	AMZN	LONG	EXIT	299	81686.30
# FILL	2013-03-15 00:00:00	AMZN	LONG	BUY	301	79399.83
# FILL	2013-06-18 00:00:00	AMZN	LONG	EXIT	301	84391.29
# FILL	2013-06-21 00:00:00	SPY	LONG	BUY	532	78615.36
# FILL	2013-07-11 00:00:00	SPY	LONG	EXIT	532	82388.98
# FILL	2013-07-25 00:00:00	FB	LONG	EXIT	2567	86759.70
# FILL	2013-08-01 00:00:00	FB	LONG	BUY	2490	93683.27
# FILL	2013-08-26 00:00:00	FB	LONG	EXIT	2490	102735.80
# FILL	2013-08-28 00:00:00	FB	LONG	BUY	2437	98418.69
# FILL	2013-09-06 00:00:00	FB	LONG	EXIT	2437	105968.68
# FILL	2013-09-17 00:00:00	FB	LONG	BUY	2380	104617.58
# FILL	2013-09-20 00:00:00	FB	LONG	EXIT	2380	111019.06
# FILL	2013-10-04 00:00:00	FB	LONG	BUY	2097	105668.21
# FILL	2013-10-08 00:00:00	AMZN	LONG	BUY	330	101000.77
# FILL	2013-10-18 00:00:00	FB	LONG	EXIT	2097	113632.01
# FILL	2013-10-21 00:00:00	AMZN	LONG	EXIT	330	107823.06
# FILL	2013-10-23 00:00:00	FB	LONG	BUY	2159	111654.51
# FILL	2013-11-08 00:00:00	AMZN	LONG	BUY	310	107792.82
# FILL	2013-11-15 00:00:00	AMZN	LONG	EXIT	310	114402.52
# FILL	2013-12-17 00:00:00	FB	LONG	EXIT	2159	118059.83
# FILL	2013-12-30 00:00:00	FB	LONG	BUY	2152	116922.79
# FILL	2014-01-07 00:00:00	FB	LONG	EXIT	2152	124506.24
# FILL	2014-01-14 00:00:00	FB	LONG	BUY	2161	123108.86
# FILL	2014-01-27 00:00:00	AMZN	LONG	BUY	306	118571.53
# FILL	2014-01-30 00:00:00	FB	LONG	EXIT	2161	132791.85
# FILL	2014-02-04 00:00:00	GOOG	LONG	BUY	212	121416.06
# FILL	2014-02-19 00:00:00	GOOG	LONG	EXIT	212	127365.23
# FILL	2014-03-12 00:00:00	FB	LONG	BUY	1812	127220.68
# FILL	2014-07-24 00:00:00	FB	LONG	EXIT	1812	136963.98
# FILL	2014-08-01 00:00:00	FB	LONG	BUY	1708	123695.40
# FILL	2014-09-03 00:00:00	FB	LONG	EXIT	1708	130664.96
# FILL	2014-09-16 00:00:00	FB	LONG	BUY	1741	130030.64
# FILL	2014-09-25 00:00:00	FB	LONG	EXIT	1741	135791.00
# FILL	2014-09-26 00:00:00	GOOG	LONG	BUY	227	131034.86
# FILL	2015-04-24 00:00:00	AMZN	LONG	EXIT	306	136354.24
# FILL	2015-04-24 00:00:00	FB	LONG	BUY	1796	147722.99
# FILL	2015-06-24 00:00:00	FB	LONG	EXIT	1796	158597.26
# FILL	2015-06-30 00:00:00	FB	LONG	BUY	1726	148743.34
# FILL	2015-07-17 00:00:00	FB	LONG	EXIT	1726	162102.50
# FILL	2015-07-17 00:00:00	GOOG	LONG	EXIT	227	149684.74
# FILL	2015-07-24 00:00:00	GOOG	LONG	BUY	264	167814.95
# FILL	2015-07-28 00:00:00	FB	LONG	BUY	1802	170256.95
# FILL	2015-08-11 00:00:00	GOOG	LONG	EXIT	264	175362.72
# FILL	2015-08-21 00:00:00	AMZN	LONG	BUY	332	167212.37
# FILL	2015-09-14 00:00:00	AMZN	LONG	EXIT	332	174383.75
# FILL	2015-09-21 00:00:00	GOOG	LONG	BUY	281	177460.10
# FILL	2015-10-16 00:00:00	GOOG	LONG	EXIT	281	185672.00
# FILL	2015-10-21 00:00:00	AMZN	LONG	BUY	328	183405.94
# FILL	2015-10-23 00:00:00	AMZN	LONG	EXIT	328	199129.23
# FILL	2015-10-23 00:00:00	FB	LONG	EXIT	1802	182820.56
# FILL	2015-11-02 00:00:00	FB	LONG	BUY	1936	198200.25
# FILL	2015-11-05 00:00:00	FB	LONG	EXIT	1936	211499.00
# FILL	2015-11-16 00:00:00	AMZN	LONG	BUY	317	201757.20
# FILL	2015-11-16 00:00:00	FB	LONG	BUY	1970	201671.18
# FILL	2015-11-23 00:00:00	AMZN	LONG	EXIT	317	214325.85
# FILL	2015-12-14 00:00:00	AMZN	LONG	BUY	326	211004.64
# FILL	2015-12-17 00:00:00	AMZN	LONG	EXIT	326	220453.17
# FILL	2016-01-05 00:00:00	AMZN	LONG	BUY	332	211682.75
# FILL	2016-01-29 00:00:00	FB	LONG	EXIT	1970	218245.61
# FILL	2016-02-04 00:00:00	GOOG	LONG	BUY	282	201569.99
# FILL	2016-04-14 00:00:00	GOOG	LONG	EXIT	282	212805.66
# FILL	2016-04-25 00:00:00	FB	LONG	BUY	2047	225016.34
# FILL	2016-04-28 00:00:00	FB	LONG	EXIT	2047	242468.68
# FILL	2016-04-29 00:00:00	GOOG	LONG	BUY	350	242779.83
# FILL	2016-05-03 00:00:00	AMZN	LONG	EXIT	332	224109.07
# FILL	2016-05-18 00:00:00	AMZN	LONG	BUY	353	245687.23
# FILL	2016-05-31 00:00:00	GOOG	LONG	EXIT	350	257294.54
# FILL	2016-06-14 00:00:00	FB	LONG	BUY	2222	254023.78
# FILL	2016-07-07 00:00:00	AMZN	LONG	EXIT	353	259533.44
# FILL	2016-07-20 00:00:00	FB	LONG	EXIT	2222	269571.50
# FILL	2016-09-12 00:00:00	AMZN	LONG	BUY	350	267649.25
# FILL	2016-09-12 00:00:00	FB	LONG	BUY	2088	265841.29
# FILL	2016-09-23 00:00:00	AMZN	LONG	EXIT	350	281586.39
# FILL	2016-10-31 00:00:00	AMZN	LONG	BUY	354	278703.65

# %%
fund.fund.performance_summary()
# Out:
#                    total equity     max equity  max drawdown  max duration  \
# long_buy_the_dip  520975.646755  557544.112585      0.203248         106.0
# bench             202049.030403  202049.030403      0.201485         194.0
# fund              723024.677158  748137.796727      0.178282         114.0
#
#                   sharpe ratio  avg positions  annualized returns
# long_buy_the_dip      1.281072        1.59641            1.318576
# bench                 0.872991        1.00000            1.125080
# fund                  1.268977        2.59641            1.240272

# %%
v = Visualizer()

# %%
plt.figure(figsize=(17, 8))
ax1 = plt.subplot(211)
ax1 = v.equity(fund.fund, ax=ax1)
ax2 = plt.subplot(212, sharex=ax1)
ax2 = v.positions(fund.fund, ax=ax2)
plt.show()

# %%
plt.figure(figsize=(17, 8))
ax1 = plt.subplot(211)
ax1 = v.drawdown_percentage(fund.fund, ax=ax1)
ax2 = plt.subplot(212, sharex=ax1)
ax2 = v.drawdown_duration(fund.fund, ax=ax2)
plt.show()

# %%
plt.figure(figsize=(17, 4))
ax1 = plt.subplot(121)
ax1 = v.monthly_returns(fund.fund, ax=ax1)
ax2 = plt.subplot(122)
ax2 = v.yearly_returns(fund.fund, ax=ax2)
plt.show()
