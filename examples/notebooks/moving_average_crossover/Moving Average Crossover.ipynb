# %%
import fund
import settings
import handlers

# %%
from odin.metrics import Visualizer

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
fund.fund.trade()
# Out:
# FILL	2006-01-03 00:00:00	AAPL	LONG	BUY	10788	101593.37
# FILL	2006-06-22 00:00:00	AAPL	LONG	EXIT	10788	81345.36
# FILL	2006-09-26 00:00:00	AAPL	LONG	BUY	8163	80470.93
# FILL	2008-03-07 00:00:00	AAPL	LONG	EXIT	8163	126442.12
# FILL	2008-05-19 00:00:00	AAPL	LONG	BUY	5218	123680.50
# FILL	2008-09-24 00:00:00	AAPL	LONG	EXIT	5218	85523.69
# FILL	2009-05-14 00:00:00	AAPL	LONG	BUY	5692	88692.94
# FILL	2012-12-11 00:00:00	AAPL	LONG	EXIT	5692	399465.33
# FILL	2013-09-11 00:00:00	AAPL	LONG	BUY	6472	400098.10
# FILL	2015-08-31 00:00:00	AAPL	LONG	EXIT	6472	702387.79
# FILL	2016-08-31 00:00:00	AAPL	LONG	BUY	6768	703494.83

# %%
fund.fund.performance_summary()
# Out:
#                           total equity    max equity  max drawdown  \
# moving_average_crossover  1.181813e+06  1.181881e+06      0.581961
# fund                      1.181813e+06  1.181881e+06      0.581961
#
#                           max duration  sharpe ratio  avg positions  \
# moving_average_crossover         689.0      0.876582       0.760681
# fund                             689.0      0.876582       0.760681
#
#                           annualized returns  prop positive days
# moving_average_crossover            1.230932            0.415554
# fund                                1.230932            0.415554

# %%
v = Visualizer()

# %%
plt.figure(figsize=(17, 8))
ax1 = plt.subplot(211)
ax1 = v.equity(fund.fund, ax=ax1)
ax2 = plt.subplot(212, sharex=ax1)
ax2 = v.positions(fund.fund, ax=ax2)
plt.show()
