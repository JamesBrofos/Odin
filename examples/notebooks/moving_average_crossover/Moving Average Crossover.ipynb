# %%
import fund
import settings
import handlers

# %%
from odin.metrics import Visualizer

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
fund.fund.trade()
# Out:
# FILL	2006-01-03 00:00:00	AAPL	LONG	BUY	10617	101590.84
# FILL	2006-06-22 00:00:00	AAPL	LONG	EXIT	10617	81343.32
# FILL	2006-09-26 00:00:00	AAPL	LONG	BUY	8034	80472.84
# FILL	2008-03-07 00:00:00	AAPL	LONG	EXIT	8034	126445.13
# FILL	2008-05-19 00:00:00	AAPL	LONG	BUY	5135	123670.41
# FILL	2008-09-24 00:00:00	AAPL	LONG	EXIT	5135	85516.73
# FILL	2009-05-14 00:00:00	AAPL	LONG	BUY	5603	88710.11
# FILL	2012-12-11 00:00:00	AAPL	LONG	EXIT	5603	399542.53
# FILL	2013-09-11 00:00:00	AAPL	LONG	BUY	6371	400187.85
# FILL	2015-08-31 00:00:00	AAPL	LONG	EXIT	6371	702545.27
# FILL	2016-08-31 00:00:00	AAPL	LONG	BUY	6662	703612.44

# %%
fund.fund.performance_summary()
# Out:
#                            total equity     max equity  max drawdown  \
# moving_average_crossover  773879.884355  825102.707557       0.58193
# fund                      773879.884355  825102.707557       0.58193
#
#                           max duration  sharpe ratio  avg positions  \
# moving_average_crossover         689.0       0.78913       0.741062
# fund                             689.0       0.78913       0.741062
#
#                           annualized returns
# moving_average_crossover             1.20475
# fund                                 1.20475

# %%
v = Visualizer()

# %%
plt.figure(figsize=(17, 8))
ax1 = plt.subplot(211)
ax1 = v.equity(fund.fund, ax=ax1)
ax2 = plt.subplot(212, sharex=ax1)
ax2 = v.positions(fund.fund, ax=ax2)
plt.show()
